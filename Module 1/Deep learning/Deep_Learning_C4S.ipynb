# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Loading codebook file

# %%
def load_codebook(fname):
  df = pd.read_csv(fname)
  y = df[["x0", "x1", "x2", "x3", "x4", "x5", "x6"]].values
  m = df[["m0", "m1", "m2", "m3"]].values
  file_size = y.shape[0]
  m_modified = np.zeros(file_size)
  for i in range(file_size):
    m_modified[i] += m[i,0]*8+m[i,1]*4+m[i,2]*2+m[i,3]*1
  return y, m_modified, file_size

# %% [markdown]
# **Splitting** data into training and testing

# %%
def splitting_data(y,m,rate,file_size):
  train_size = round(file_size*rate)
  test_size = file_size - train_size
  train_y = y[0:train_size,:]
  train_m = m[0:train_size]
  test_y = y[train_size:file_size,:]
  test_m = m[train_size:file_size]
  return train_y, train_m, test_y, test_m, train_size, test_size

# %% [markdown]
# # Compiling the model

# %%
def model_compile(SNR):
    learning_rate = 0.001/(SNR+1)
    opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(128, activation='relu', input_shape=(7,)))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dense(16, activation='softmax'))

    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Main Function

# %%
SNR_start = 0
SNR_end = 7
step_size = 1
SNR = np.arange(SNR_start,SNR_end+1,step_size)
length_SNR = len(SNR)
BLER = np.zeros(length_SNR)
rate = 0.3 # training data rate
for i in range(length_SNR):
  fname = "codeword_file_SNR="+str(SNR[i])+".csv"
  [y,m,file_size] = load_codebook(fname)
  [train_y,train_m,test_y,test_m,train_size,test_size] = splitting_data(y,m,rate,file_size)

  unique_category_count = 16
  train_m_OneHot=tf.one_hot(train_m, unique_category_count)
  test_m_OneHot=tf.one_hot(test_m, unique_category_count)

  model = model_compile(SNR[i])
  
  if SNR[i]>=5:
    num_epochs = 5
  elif SNR[i]>=2:
    num_epochs = 40
  else:
    num_epochs = 25
    
  history = model.fit(train_y, train_m_OneHot, epochs=num_epochs, batch_size=64, validation_data=(test_y, test_m_OneHot))

  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.legend(['training', 'validation'], loc = 'upper left')
  plt.show()

  pred = model.predict(test_y)
  pred_m = np.argmax(pred, axis=1)
  BLER[i] = np.mean(np.not_equal(pred_m, test_m))
  
  print("BLER: ",BLER[i])
  print(i,"/",len(BLER)-1)
#Reuse the results of last time
BLER_SymdromeDecoding = [0.26725, 0.187, 0.114, 0.068, 0.036375, 0.01578, 0.005475, 0.00147, 0.00029033]
BLER_SVM = [0.191, 0.1335, 0.0755, 0.046, 0.01305, 0.00412, 0.00109, 0.000275]
BLER_ML = [1.7625e-01, 1.1075e-01, 5.8000e-02, 3.3500e-02, 1.1275e-02, 3.3550e-03, 8.0000e-04, 1.3000e-04]
#Plot BLER
EbN0dBs = np.arange(start=SNR_start,stop=SNR_end+1,step=step_size)
fig1 = plt.figure(1)
plt.semilogy(EbN0dBs,BLER,color='r',marker='o',linestyle='-',label='Deep_Learning')
plt.xlabel('$E_b/N_0(dB)$');plt.ylabel('BLER ($P_b$)')
plt.title('Probability of block error over AWGN channel')
plt.xlim(SNR_start,SNR_end);plt.grid(True);
plt.legend()
print("Block Error Rate:", BLER)
fig2 = plt.figure(2)
plt.semilogy(EbN0dBs,BLER_SymdromeDecoding[SNR_start:SNR_end+1],marker='o',linestyle='-',label='Symdrome_Decoding')
plt.semilogy(EbN0dBs,BLER_SVM[SNR_start:SNR_end+1],marker='o',linestyle='-',label='SVM')
plt.semilogy(EbN0dBs,BLER_ML[SNR_start:SNR_end+1],marker='o',linestyle='-',label='ML_Decoding')
plt.semilogy(EbN0dBs,BLER,marker='o',linestyle='-',label='Deep_Learning')
plt.xlabel('$E_b/N_0(dB)$');plt.ylabel('BLER ($P_b$)')
plt.title('Probability of block error over AWGN channel')
plt.xlim(SNR_start,SNR_end);plt.grid(True);
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# 19/19 [==============================] - 2s 21ms/step - loss: 2.5098 - accuracy: 0.3758 - val_loss: 2.1668 - val_accuracy: 0.5250
# Epoch 2/25
# 19/19 [==============================] - 0s 13ms/step - loss: 1.7221 - accuracy: 0.6108 - val_loss: 1.2782 - val_accuracy: 0.7114
# Epoch 3/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.9592 - accuracy: 0.7683 - val_loss: 0.7720 - val_accuracy: 0.7879
# Epoch 4/25
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6649 - accuracy: 0.7942 - val_loss: 0.6576 - val_accuracy: 0.7914
# Epoch 5/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.5995 - accuracy: 0.8083 - val_loss: 0.6368 - val_accuracy: 0.7982
# Epoch 6/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.5654 - accuracy: 0.8108 - val_loss: 0.6231 - val_accuracy: 0.7968
# Epoch 7/25
# 19/19 [==============================] - 0s 9ms/step - loss: 0.5647 - accuracy: 0.8125 - val_loss: 0.6209 - val_accuracy: 0.7943
# Epoch 8/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.5288 - accuracy: 0.8200 - val_loss: 0.6008 - val_accuracy: 0.8025
# Epoch 9/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4986 - accuracy: 0.8333 - val_loss: 0.6059 - val_accuracy: 0.8021
# Epoch 10/25
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4909 - accuracy: 0.8292 - val_loss: 0.6212 - val_accuracy: 0.7993
# Epoch 11/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4873 - accuracy: 0.8333 - val_loss: 0.6087 - val_accuracy: 0.8000
# Epoch 12/25
# 19/19 [==============================] - 0s 17ms/step - loss: 0.4762 - accuracy: 0.8342 - val_loss: 0.6176 - val_accuracy: 0.8029
# Epoch 13/25
# 19/19 [==============================] - 0s 20ms/step - loss: 0.4727 - accuracy: 0.8433 - val_loss: 0.6301 - val_accuracy: 0.7961
# Epoch 14/25
# 19/19 [==============================] - 0s 18ms/step - loss: 0.4568 - accuracy: 0.8442 - val_loss: 0.6182 - val_accuracy: 0.8011
# Epoch 15/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4487 - accuracy: 0.8483 - val_loss: 0.6283 - val_accuracy: 0.7993
# Epoch 16/25
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4439 - accuracy: 0.8500 - val_loss: 0.6613 - val_accuracy: 0.7886
# Epoch 17/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4351 - accuracy: 0.8508 - val_loss: 0.6293 - val_accuracy: 0.7989
# Epoch 18/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4226 - accuracy: 0.8567 - val_loss: 0.6316 - val_accuracy: 0.7989
# Epoch 19/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4215 - accuracy: 0.8617 - val_loss: 0.6477 - val_accuracy: 0.7943
# Epoch 20/25
# 19/19 [==============================] - 0s 15ms/step - loss: 0.4130 - accuracy: 0.8542 - val_loss: 0.6469 - val_accuracy: 0.7936
# Epoch 21/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4054 - accuracy: 0.8575 - val_loss: 0.6557 - val_accuracy: 0.7914
# Epoch 22/25
# 19/19 [==============================] - 0s 12ms/step - loss: 0.4052 - accuracy: 0.8592 - val_loss: 0.6545 - val_accuracy: 0.7943
# Epoch 23/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3913 - accuracy: 0.8650 - val_loss: 0.6692 - val_accuracy: 0.7921
# Epoch 24/25
# 19/19 [==============================] - 0s 14ms/step - loss: 0.3853 - accuracy: 0.8683 - val_loss: 0.6605 - val_accuracy: 0.7971
# Epoch 25/25
# 19/19 [==============================] - 0s 11ms/step - loss: 0.3820 - accuracy: 0.8708 - val_loss: 0.6695 - val_accuracy: 0.7929
# 88/88 [==============================] - 0s 2ms/step
# BLER:  0.20714285714285716
# 0 / 7
# Epoch 1/25
# 19/19 [==============================] - 39s 2s/step - loss: 2.6447 - accuracy: 0.3217 - val_loss: 2.4812 - val_accuracy: 0.5557
# Epoch 2/25
# 19/19 [==============================] - 0s 9ms/step - loss: 2.2680 - accuracy: 0.6533 - val_loss: 2.0456 - val_accuracy: 0.6607
# Epoch 3/25
# 19/19 [==============================] - 0s 13ms/step - loss: 1.7189 - accuracy: 0.7325 - val_loss: 1.4496 - val_accuracy: 0.7614
# Epoch 4/25
# 19/19 [==============================] - 0s 9ms/step - loss: 1.1182 - accuracy: 0.8242 - val_loss: 0.9123 - val_accuracy: 0.8386
# Epoch 5/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.7029 - accuracy: 0.8700 - val_loss: 0.6306 - val_accuracy: 0.8586
# Epoch 6/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.5081 - accuracy: 0.8808 - val_loss: 0.5097 - val_accuracy: 0.8696
# Epoch 7/25
# 19/19 [==============================] - 0s 9ms/step - loss: 0.4271 - accuracy: 0.8842 - val_loss: 0.4620 - val_accuracy: 0.8711
# Epoch 8/25
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3812 - accuracy: 0.8975 - val_loss: 0.4381 - val_accuracy: 0.8707
# Epoch 9/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3513 - accuracy: 0.9033 - val_loss: 0.4256 - val_accuracy: 0.8711
# Epoch 10/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3322 - accuracy: 0.9008 - val_loss: 0.4096 - val_accuracy: 0.8725
# Epoch 11/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3197 - accuracy: 0.9025 - val_loss: 0.4174 - val_accuracy: 0.8671
# Epoch 12/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3065 - accuracy: 0.9058 - val_loss: 0.4039 - val_accuracy: 0.8739
# Epoch 13/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2965 - accuracy: 0.9017 - val_loss: 0.4095 - val_accuracy: 0.8689
# Epoch 14/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2905 - accuracy: 0.9083 - val_loss: 0.4028 - val_accuracy: 0.8771
# Epoch 15/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2829 - accuracy: 0.9108 - val_loss: 0.4153 - val_accuracy: 0.8661
# Epoch 16/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2779 - accuracy: 0.9100 - val_loss: 0.4075 - val_accuracy: 0.8682
# Epoch 17/25
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2667 - accuracy: 0.9125 - val_loss: 0.4111 - val_accuracy: 0.8704
# Epoch 18/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2629 - accuracy: 0.9150 - val_loss: 0.4131 - val_accuracy: 0.8643
# Epoch 19/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2580 - accuracy: 0.9117 - val_loss: 0.4108 - val_accuracy: 0.8686
# Epoch 20/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2520 - accuracy: 0.9183 - val_loss: 0.4191 - val_accuracy: 0.8675
# Epoch 21/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2472 - accuracy: 0.9208 - val_loss: 0.4074 - val_accuracy: 0.8714
# Epoch 22/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2420 - accuracy: 0.9217 - val_loss: 0.4235 - val_accuracy: 0.8611
# Epoch 23/25
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2371 - accuracy: 0.9225 - val_loss: 0.4169 - val_accuracy: 0.8654
# Epoch 24/25
# 19/19 [==============================] - 0s 11ms/step - loss: 0.2317 - accuracy: 0.9225 - val_loss: 0.4170 - val_accuracy: 0.8661
# Epoch 25/25
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2294 - accuracy: 0.9250 - val_loss: 0.4329 - val_accuracy: 0.8614
# 88/88 [==============================] - 0s 1ms/step
# BLER:  0.13857142857142857
# 1 / 7
# Epoch 1/40
# 19/19 [==============================] - 2s 22ms/step - loss: 2.7063 - accuracy: 0.1250 - val_loss: 2.5684 - val_accuracy: 0.3682
# Epoch 2/40
# 19/19 [==============================] - 0s 13ms/step - loss: 2.4234 - accuracy: 0.5358 - val_loss: 2.2706 - val_accuracy: 0.6496
# Epoch 3/40
# 19/19 [==============================] - 0s 10ms/step - loss: 2.0651 - accuracy: 0.7217 - val_loss: 1.8595 - val_accuracy: 0.7525
# Epoch 4/40
# 19/19 [==============================] - 0s 10ms/step - loss: 1.5975 - accuracy: 0.8025 - val_loss: 1.3711 - val_accuracy: 0.8100
# Epoch 5/40
# 19/19 [==============================] - 0s 9ms/step - loss: 1.1244 - accuracy: 0.8517 - val_loss: 0.9352 - val_accuracy: 0.8707
# Epoch 6/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.7625 - accuracy: 0.8917 - val_loss: 0.6424 - val_accuracy: 0.9093
# Epoch 7/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5403 - accuracy: 0.9167 - val_loss: 0.4785 - val_accuracy: 0.9154
# Epoch 8/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.4116 - accuracy: 0.9283 - val_loss: 0.3842 - val_accuracy: 0.9232
# Epoch 9/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3386 - accuracy: 0.9292 - val_loss: 0.3306 - val_accuracy: 0.9261
# Epoch 10/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2898 - accuracy: 0.9408 - val_loss: 0.2951 - val_accuracy: 0.9321
# Epoch 11/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2570 - accuracy: 0.9458 - val_loss: 0.2724 - val_accuracy: 0.9321
# Epoch 12/40
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2323 - accuracy: 0.9483 - val_loss: 0.2545 - val_accuracy: 0.9354
# Epoch 13/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2144 - accuracy: 0.9517 - val_loss: 0.2432 - val_accuracy: 0.9343
# Epoch 14/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1988 - accuracy: 0.9542 - val_loss: 0.2330 - val_accuracy: 0.9343
# Epoch 15/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1875 - accuracy: 0.9550 - val_loss: 0.2260 - val_accuracy: 0.9371
# Epoch 16/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1772 - accuracy: 0.9575 - val_loss: 0.2205 - val_accuracy: 0.9361
# Epoch 17/40
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1687 - accuracy: 0.9550 - val_loss: 0.2195 - val_accuracy: 0.9343
# Epoch 18/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1613 - accuracy: 0.9608 - val_loss: 0.2147 - val_accuracy: 0.9357
# Epoch 19/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1569 - accuracy: 0.9583 - val_loss: 0.2147 - val_accuracy: 0.9354
# Epoch 20/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1519 - accuracy: 0.9608 - val_loss: 0.2138 - val_accuracy: 0.9321
# Epoch 21/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1442 - accuracy: 0.9625 - val_loss: 0.2100 - val_accuracy: 0.9339
# Epoch 22/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.9633 - val_loss: 0.2109 - val_accuracy: 0.9321
# Epoch 23/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1369 - accuracy: 0.9658 - val_loss: 0.2095 - val_accuracy: 0.9343
# Epoch 24/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1327 - accuracy: 0.9625 - val_loss: 0.2077 - val_accuracy: 0.9332
# Epoch 25/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1267 - accuracy: 0.9675 - val_loss: 0.2089 - val_accuracy: 0.9325
# Epoch 26/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1235 - accuracy: 0.9708 - val_loss: 0.2076 - val_accuracy: 0.9354
# Epoch 27/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1204 - accuracy: 0.9675 - val_loss: 0.2106 - val_accuracy: 0.9307
# Epoch 28/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1171 - accuracy: 0.9683 - val_loss: 0.2076 - val_accuracy: 0.9357
# Epoch 29/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1147 - accuracy: 0.9692 - val_loss: 0.2101 - val_accuracy: 0.9311
# Epoch 30/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1135 - accuracy: 0.9692 - val_loss: 0.2099 - val_accuracy: 0.9339
# Epoch 31/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1107 - accuracy: 0.9733 - val_loss: 0.2102 - val_accuracy: 0.9329
# Epoch 32/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1081 - accuracy: 0.9683 - val_loss: 0.2116 - val_accuracy: 0.9325
# Epoch 33/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1058 - accuracy: 0.9717 - val_loss: 0.2109 - val_accuracy: 0.9346
# Epoch 34/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1033 - accuracy: 0.9700 - val_loss: 0.2143 - val_accuracy: 0.9293
# Epoch 35/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1015 - accuracy: 0.9750 - val_loss: 0.2130 - val_accuracy: 0.9321
# Epoch 36/40
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0975 - accuracy: 0.9758 - val_loss: 0.2150 - val_accuracy: 0.9304
# Epoch 37/40
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0961 - accuracy: 0.9750 - val_loss: 0.2175 - val_accuracy: 0.9304
# Epoch 38/40
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0947 - accuracy: 0.9750 - val_loss: 0.2169 - val_accuracy: 0.9307
# Epoch 39/40
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0924 - accuracy: 0.9758 - val_loss: 0.2190 - val_accuracy: 0.9282
# Epoch 40/40
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0922 - accuracy: 0.9758 - val_loss: 0.2181 - val_accuracy: 0.9304
# 88/88 [==============================] - 0s 2ms/step
# BLER:  0.06964285714285715
# 2 / 7
# Epoch 1/40
# 19/19 [==============================] - 2s 21ms/step - loss: 2.6679 - accuracy: 0.1533 - val_loss: 2.5334 - val_accuracy: 0.3332
# Epoch 2/40
# 19/19 [==============================] - 0s 13ms/step - loss: 2.4040 - accuracy: 0.5458 - val_loss: 2.2652 - val_accuracy: 0.7246
# Epoch 3/40
# 19/19 [==============================] - 0s 10ms/step - loss: 2.1017 - accuracy: 0.8108 - val_loss: 1.9336 - val_accuracy: 0.8582
# Epoch 4/40
# 19/19 [==============================] - 0s 13ms/step - loss: 1.7303 - accuracy: 0.8892 - val_loss: 1.5399 - val_accuracy: 0.8961
# Epoch 5/40
# 19/19 [==============================] - 0s 13ms/step - loss: 1.3210 - accuracy: 0.9208 - val_loss: 1.1401 - val_accuracy: 0.9250
# Epoch 6/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.9421 - accuracy: 0.9392 - val_loss: 0.8021 - val_accuracy: 0.9393
# Epoch 7/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.6558 - accuracy: 0.9525 - val_loss: 0.5690 - val_accuracy: 0.9486
# Epoch 8/40
# 19/19 [==============================] - 0s 11ms/step - loss: 0.4688 - accuracy: 0.9592 - val_loss: 0.4242 - val_accuracy: 0.9507
# Epoch 9/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3540 - accuracy: 0.9633 - val_loss: 0.3378 - val_accuracy: 0.9529
# Epoch 10/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2847 - accuracy: 0.9650 - val_loss: 0.2805 - val_accuracy: 0.9575
# Epoch 11/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.2392 - accuracy: 0.9650 - val_loss: 0.2442 - val_accuracy: 0.9571
# Epoch 12/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.2071 - accuracy: 0.9658 - val_loss: 0.2171 - val_accuracy: 0.9568
# Epoch 13/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1836 - accuracy: 0.9667 - val_loss: 0.1975 - val_accuracy: 0.9593
# Epoch 14/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1655 - accuracy: 0.9675 - val_loss: 0.1825 - val_accuracy: 0.9600
# Epoch 15/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1524 - accuracy: 0.9683 - val_loss: 0.1707 - val_accuracy: 0.9614
# Epoch 16/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1411 - accuracy: 0.9700 - val_loss: 0.1625 - val_accuracy: 0.9611
# Epoch 17/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1314 - accuracy: 0.9725 - val_loss: 0.1548 - val_accuracy: 0.9614
# Epoch 18/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1231 - accuracy: 0.9717 - val_loss: 0.1476 - val_accuracy: 0.9621
# Epoch 19/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1160 - accuracy: 0.9742 - val_loss: 0.1427 - val_accuracy: 0.9625
# Epoch 20/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1098 - accuracy: 0.9750 - val_loss: 0.1376 - val_accuracy: 0.9614
# Epoch 21/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.1046 - accuracy: 0.9767 - val_loss: 0.1365 - val_accuracy: 0.9600
# Epoch 22/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0993 - accuracy: 0.9767 - val_loss: 0.1311 - val_accuracy: 0.9614
# Epoch 23/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0953 - accuracy: 0.9775 - val_loss: 0.1285 - val_accuracy: 0.9611
# Epoch 24/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0918 - accuracy: 0.9792 - val_loss: 0.1259 - val_accuracy: 0.9618
# Epoch 25/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0887 - accuracy: 0.9783 - val_loss: 0.1255 - val_accuracy: 0.9621
# Epoch 26/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0856 - accuracy: 0.9783 - val_loss: 0.1228 - val_accuracy: 0.9614
# Epoch 27/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0825 - accuracy: 0.9808 - val_loss: 0.1214 - val_accuracy: 0.9629
# Epoch 28/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0787 - accuracy: 0.9825 - val_loss: 0.1201 - val_accuracy: 0.9632
# Epoch 29/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0763 - accuracy: 0.9833 - val_loss: 0.1200 - val_accuracy: 0.9618
# Epoch 30/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0738 - accuracy: 0.9867 - val_loss: 0.1179 - val_accuracy: 0.9614
# Epoch 31/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0712 - accuracy: 0.9850 - val_loss: 0.1169 - val_accuracy: 0.9618
# Epoch 32/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0692 - accuracy: 0.9867 - val_loss: 0.1158 - val_accuracy: 0.9618
# Epoch 33/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0672 - accuracy: 0.9867 - val_loss: 0.1145 - val_accuracy: 0.9607
# Epoch 34/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0651 - accuracy: 0.9875 - val_loss: 0.1148 - val_accuracy: 0.9607
# Epoch 35/40
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0634 - accuracy: 0.9875 - val_loss: 0.1140 - val_accuracy: 0.9611
# Epoch 36/40
# 19/19 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.9917 - val_loss: 0.1149 - val_accuracy: 0.9600
# Epoch 37/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0602 - accuracy: 0.9858 - val_loss: 0.1120 - val_accuracy: 0.9604
# Epoch 38/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0581 - accuracy: 0.9908 - val_loss: 0.1134 - val_accuracy: 0.9600
# Epoch 39/40
# 19/19 [==============================] - 0s 10ms/step - loss: 0.0566 - accuracy: 0.9908 - val_loss: 0.1132 - val_accuracy: 0.9600
# Epoch 40/40
# 19/19 [==============================] - 0s 11ms/step - loss: 0.0551 - accuracy: 0.9917 - val_loss: 0.1121 - val_accuracy: 0.9614
# 88/88 [==============================] - 0s 2ms/step
# BLER:  0.03857142857142857
# 3 / 7
# Epoch 1/40
# 188/188 [==============================] - 4s 11ms/step - loss: 1.5075 - accuracy: 0.7626 - val_loss: 0.3080 - val_accuracy: 0.9806
# Epoch 2/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.1560 - accuracy: 0.9834 - val_loss: 0.0899 - val_accuracy: 0.9860
# Epoch 3/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0733 - accuracy: 0.9866 - val_loss: 0.0623 - val_accuracy: 0.9858
# Epoch 4/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0548 - accuracy: 0.9876 - val_loss: 0.0520 - val_accuracy: 0.9861
# Epoch 5/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0470 - accuracy: 0.9882 - val_loss: 0.0461 - val_accuracy: 0.9867
# Epoch 6/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0428 - accuracy: 0.9882 - val_loss: 0.0433 - val_accuracy: 0.9874
# Epoch 7/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0396 - accuracy: 0.9884 - val_loss: 0.0430 - val_accuracy: 0.9865
# Epoch 8/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 0.0420 - val_accuracy: 0.9866
# Epoch 9/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0358 - accuracy: 0.9889 - val_loss: 0.0426 - val_accuracy: 0.9864
# Epoch 10/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0351 - accuracy: 0.9887 - val_loss: 0.0411 - val_accuracy: 0.9859
# Epoch 11/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.0406 - val_accuracy: 0.9864
# Epoch 12/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.0396 - val_accuracy: 0.9870
# Epoch 13/40
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.0400 - val_accuracy: 0.9866
# Epoch 14/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.0436 - val_accuracy: 0.9850
# Epoch 15/40
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.0409 - val_accuracy: 0.9863
# Epoch 16/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.0417 - val_accuracy: 0.9854
# Epoch 17/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0281 - accuracy: 0.9918 - val_loss: 0.0415 - val_accuracy: 0.9861
# Epoch 18/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0279 - accuracy: 0.9915 - val_loss: 0.0406 - val_accuracy: 0.9866
# Epoch 19/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0270 - accuracy: 0.9915 - val_loss: 0.0437 - val_accuracy: 0.9852
# Epoch 20/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0268 - accuracy: 0.9919 - val_loss: 0.0412 - val_accuracy: 0.9867
# Epoch 21/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0262 - accuracy: 0.9919 - val_loss: 0.0424 - val_accuracy: 0.9855
# Epoch 22/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.0424 - val_accuracy: 0.9857
# Epoch 23/40
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0420 - val_accuracy: 0.9864
# Epoch 24/40
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.0422 - val_accuracy: 0.9864
# Epoch 25/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 0.0431 - val_accuracy: 0.9855
# Epoch 26/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.0443 - val_accuracy: 0.9854
# Epoch 27/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0233 - accuracy: 0.9928 - val_loss: 0.0457 - val_accuracy: 0.9851
# Epoch 28/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0228 - accuracy: 0.9934 - val_loss: 0.0432 - val_accuracy: 0.9856
# Epoch 29/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 0.0435 - val_accuracy: 0.9859
# Epoch 30/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0221 - accuracy: 0.9935 - val_loss: 0.0438 - val_accuracy: 0.9856
# Epoch 31/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.0455 - val_accuracy: 0.9855
# Epoch 32/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.0458 - val_accuracy: 0.9850
# Epoch 33/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.0459 - val_accuracy: 0.9853
# Epoch 34/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 0.0452 - val_accuracy: 0.9859
# Epoch 35/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.0443 - val_accuracy: 0.9859
# Epoch 36/40
# 188/188 [==============================] - 2s 11ms/step - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0489 - val_accuracy: 0.9835
# Epoch 37/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.0452 - val_accuracy: 0.9857
# Epoch 38/40
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0191 - accuracy: 0.9945 - val_loss: 0.0472 - val_accuracy: 0.9852
# Epoch 39/40
# 188/188 [==============================] - 2s 10ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 0.0463 - val_accuracy: 0.9854
# Epoch 40/40
# 188/188 [==============================] - 2s 8ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.0478 - val_accuracy: 0.9846
# 875/875 [==============================] - 1s 1ms/step
# BLER:  0.015392857142857142
# 4 / 7
# Epoch 1/5
# 938/938 [==============================] - 9s 9ms/step - loss: 0.3736 - accuracy: 0.9460 - val_loss: 0.0231 - val_accuracy: 0.9958
# Epoch 2/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0173 - accuracy: 0.9962 - val_loss: 0.0151 - val_accuracy: 0.9960
# Epoch 3/5
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.0140 - val_accuracy: 0.9956
# Epoch 4/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0118 - accuracy: 0.9963 - val_loss: 0.0126 - val_accuracy: 0.9960
# Epoch 5/5
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0128 - val_accuracy: 0.9958
# 4375/4375 [==============================] - 8s 2ms/step
# BLER:  0.0042
# 5 / 7
# Epoch 1/5
# 938/938 [==============================] - 10s 10ms/step - loss: 0.3719 - accuracy: 0.9533 - val_loss: 0.0139 - val_accuracy: 0.9988
# Epoch 2/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.0062 - val_accuracy: 0.9991
# Epoch 3/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0046 - val_accuracy: 0.9990
# Epoch 4/5
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0039 - val_accuracy: 0.9990
# Epoch 5/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0042 - val_accuracy: 0.9988
# 4375/4375 [==============================] - 8s 2ms/step
# BLER:  0.0011785714285714286
# 6 / 7
# Epoch 1/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.1846 - accuracy: 0.9772 - val_loss: 0.0034 - val_accuracy: 0.9998
# Epoch 2/5
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0014 - val_accuracy: 0.9998
# Epoch 3/5
# 1875/1875 [==============================] - 16s 9ms/step - loss: 9.7919e-04 - accuracy: 0.9998 - val_loss: 9.2444e-04 - val_accuracy: 0.9998
# Epoch 4/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 7.0007e-04 - accuracy: 0.9998 - val_loss: 0.0010 - val_accuracy: 0.9997
# Epoch 5/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 5.2583e-04 - accuracy: 0.9999 - val_loss: 9.0001e-04 - val_accuracy: 0.9997
# 8750/8750 [==============================] - 14s 2ms/step
# BLER:  0.0002535714285714286
# 7 / 7
# Block Error Rate: [0.20714286 0.13857143 0.06964286 0.03857143 0.01539286 0.0042
#  0.00117857 0.00025357]
